# %% [markdown]
# <a href="https://colab.research.google.com/github/daniivelascoo/ifp-programacion-ia/blob/main/LAB_1_1_Decodificando_ARES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 <u>PROYECTO ARES: Ingeniería de Datos y Python Core</u>
#
# # Sprint 1.1 - Núcleo Formativo 1
#
# <br>
#
# ---
#
# <br>
#
# ## 📜 La Misión
#
# La comunicación con el Rover ARES III es errática. Nos ha llegado un archivo de telemetría corrupto (`ares_logs.txt`).
#
# Tu trabajo no es entrenar una IA (todavía), sino **preparar el terreno**. Debes actuar como Ingeniero de Datos para limpiar, estructurar y analizar estos logs usando **Python puro**.
#
# <br>
#
# ---
# <br>
#
# ## 🎯 Objetivos de Aprendizaje
#
# 1.  **Parsing:** Convertir texto "sucio" en estructuras de datos (`dict`, `list`).
# 2.  **Strings:** Dominar `split`, `strip`, `find` y `slicing`.
# 3.  **Modularidad:** Uso de librerías externas y creación de funciones.
#
# <br>
#
# ---
# <br>
#
# ## 🛠️ El Laboratorio: Decodificando ARES
#
# ### 📥 Paso 0: Descarga de Datos
# Ejecuta esta celda para descargar el archivo de logs corrupto desde el servidor de la misión (Google Drive).

# %%
# Instalamos la librería de descarga (silenciosamente)
# !pip install -q gdown

# Descargamos el archivo usando su ID único
# ID extraído de tu enlace: 1vRWScFbH8rszeL7df3vDcRXlYM15Fk5U
# !gdown 1vRWScFbH8rszeL7df3vDcRXlYM15Fk5U -O ares_logs.txt

print("\n✅ Archivo 'ares_logs.txt' descargado con éxito.")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1vRWScFbH8rszeL7df3vDcRXlYM15Fk5U
# To: /content/ares_logs.txt
# 100% 66.8k/66.8k [00:00<00:00, 56.2MB/s]
#
# ✅ Archivo 'ares_logs.txt' descargado con éxito.

# %% [markdown]
# ### 🧹 Fase 1: Ingesta y Limpieza (Parsing)
#
# **Tu Misión:**
# 1. Lee el archivo `ares_logs.txt`.
# 2. Procesa cada línea para eliminar espacios vacíos al inicio/final.
# 3. Ignora las líneas que estén totalmente vacías.
# 4. **IMPORTANTE:** Almacena el resultado en una variable llamada `logs_limpios` (una lista de strings).
#
# **Pista:** Usa `with open(...)` y el método `.readlines()`.

# %%
# TU CÓDIGO AQUÍ
# Define la variable: logs_limpios = []

logs_limpios = []

# Escribe tu lógica de apertura y limpieza aquí...
# with open...

with open('ares_logs.txt', 'r') as logs: # Abrimos el archivo ares_logs.txt en modo lectura
  for log in logs:
    log_limpio = log.strip()

    if log_limpio:
      logs_limpios.append(log_limpio)

# %% [markdown]
# ### 🧩 Fase 2: Estructuración de Datos
#
# **Tu Misión:**
# Convierte esa lista de strings en una lista de diccionarios.
# Cada línea tiene el formato: `[FECHA] TIPO :: MENSAJE`.
#
# Debes crear una lista llamada `logs_estructurados` donde cada elemento sea así:
# ```python
# {
#     "timestamp": "2035-05-20 14:00:00",
#     "tipo": "INFO", # INFO, WARNING o CRITICAL
#     "mensaje": "El texto del mensaje..."
# }

# %%
# TU CÓDIGO AQUÍ
import re

PATRON = re.compile(
    r"^\[(?P<timestamp>[^\]]+)\]\s*(?P<tipo>INFO|WARNING|CRITICAL)\s*::\s*(?P<mensaje>.+)$"
)

logs_estructurados = []

def parsear_linea(linea):
    m = PATRON.match(linea.strip())
    if not m:
        return None # Devolvemos vacío cuando no cumple el formato

    return {
        "timestamp": m.group("timestamp"),
        "tipo": m.group("tipo"),
        "mensaje": m.group("mensaje"),
    }

for log in logs_limpios:
    parsed = parsear_linea(log)
    if parsed:  # solo si se ha parseado algo lo añadimos a la lista
        logs_estructurados.append(parsed)

# %% [markdown]
# ### 🌡️ Fase 3: Análisis de Temperatura
#
# **Tu Misión:**
# Calcula la temperatura media de Marte basándote en los logs de tipo `INFO`.
# El mensaje suele ser: `TEMP_EXT=-45.2C | BATTERY=...`.
#
# 1. Extrae el número (cuidado con la 'C').
# 2. Calcula la media y guárdala en una variable llamada `media_temp` (tipo float).

# %%
# TU CÓDIGO AQUÍ
media_temp = 0.0
temp_totales = 0.0

# Tu lógica de extracción...
messages = [
    data['mensaje']
    for data in logs_estructurados
    if data['tipo'] == 'INFO'
]

for m in messages:
  temp = m.split('|')[0]
  try:
    temp_formateada = float(temp.split('=')[1].split('C')[0])
    temp_totales += temp_formateada
  except ValueError:
    print(f'Dato corrupto: {temp}')

media_temp = temp_totales / len(messages)

# %% [markdown]
# ### 🚨 Fase 4: Reporte de Críticos
#
# **Tu Misión:**
# Filtra y guarda en una lista llamada `eventos_criticos` todos los diccionarios cuyo tipo sea `CRITICAL`.
#
# **Bonus**: Si te atreves, intenta filtrar la lista usando `list(filter(lambda x: ..., ...))` en lugar de un bucle `for`."

# %%
# TU CÓDIGO AQUÍ
eventos_criticos = list(filter(lambda x: x['tipo'] == 'CRITICAL', logs_estructurados))
